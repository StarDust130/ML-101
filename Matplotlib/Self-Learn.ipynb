# %%
# Import 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Line Plot 📈

# %%
# Data
days = [1, 2, 3, 4, 5] # X axis
sales = [100, 120, 90, 150, 200] # Y axis

# Create the plot
plt.plot(days, sales , marker='o' , )

# Add title and labels
plt.title('Daily Sales Over a Week')
plt.xlabel('Days')
plt.ylabel('Sales ($)')

# Show the plot
plt.show()
